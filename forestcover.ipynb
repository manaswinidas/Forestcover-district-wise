# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"]=(15,15)

# %%
df=pd.read_csv('datafile.csv', index_col=0, thousands=',')

# %%
df
# Out:
#                Geo-graphical Area  2013 Assessment - Very Dense Forest  \
# District
# Angul                        6375                                  362
# Baleshwar1                   3806                                   23
# Baragarh                     5837                                  176
# Bhadrak                      2505                                    0
# Bolangir                     6575                                   69
# Boudh                        3098                                  264
# Cuttack                      3932                                   44
# Deogarh                      2940                                  156
# Dhenkanal                    4452                                  172
# Gajpatf                      4325                                   84
# Ganjam                       8206                                  162
# Jagatsinghpur                1668                                    0
# ...

# %%
df.dtypes
# Out:
# Geo-graphical Area                       int64
# 2013 Assessment - Very Dense Forest      int64
# 2013 Assessment - Mod. Dense Forest      int64
# 2013 Assessment - Open Forest            int64
# 2013 Assessment - Total                  int64
# Percent of GA                          float64
# Change                                   int64
# Scrub                                    int64
# dtype: object

# %%
df_1=df[df.columns[0:2]]

# %%
df.columns
# Out:
# Index(['District', '2013 Assessment - Very Dense Forest',
#        '2013 Assessment - Mod. Dense Forest', '2013 Assessment - Open Forest',
#        '2013 Assessment - Total', 'Percent of GA', 'Change', 'Scrub'],
#       dtype='object')

# %%
df['Geo-graphical Area'].plot('pie', title='Area distribution of forests in Odisha', figsize=(15,15))
plt.ylabel('')
plt.show()
